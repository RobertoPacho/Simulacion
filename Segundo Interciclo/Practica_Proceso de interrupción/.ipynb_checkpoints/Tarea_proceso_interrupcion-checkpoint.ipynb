# %% [markdown]
# # UNIVERSIDAD POLITÉCNICA SALESIANA

# %% [markdown]
# ## Roberto Pacho

# %% [markdown]
# ### Práctica

# %%
import simpy
import random
import matplotlib.pyplot as pp
import numpy as np
# %matplotlib inline
# Parámetros utilizados
HOSPITALES = 2
HOSPITAL_CAMA_A = 10
HOSPITAL_CAMA_B = 10
HOSPITAL_VENT_A = 4
HOSPITAL_VENT_B = 4
INFECTADOS = 20
TASA_CRECIMIENTO = 7
PERSONAL_MEDICO = 150
DIAS_INTERNADO = 10
DIAS_SIMULACION = 20
persona_recuperadas={}
persona_fallecidas={}

# %%
class Hospital(object):
    def __init__(self, env, num_cama, name):
            self.env = env
            self.num_cama = num_cama
            self.camas = simpy.Resource(env, num_cama)
            self.name = name
            
    def ingresar_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_INTERNADO-5, DIAS_INTERNADO+5))
        print("El paciente terminó de atenderse: ", paciente, " tiempo de salida: ", self.env.now, " hospital ", self.name)

# %%
def ingreso_paciente(env, hospital, paciente):
    arrive = env.now
    estado = random.randint(1,100)
    if (estado < 60):
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,5) 
            requerimiento = yield cama | env.timeout(dias_esperando)
            wait = env.now - arrive
            if cama in requerimiento:
                print("Al paciente: ", paciente, " se le asigna una cama ", " hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                estado = random.randint(1,100)
                if (estado < 8) :
                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                else:
                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1
            else:
                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait , " dias y fallece no hay camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        
    else :
        print("El paciente no presenta covid : ", paciente, " hospital ", hospital.name )

# %%
def ejecutar(env, tasa_crecimiento, infectados):
    hospitalA = Hospital(env, HOSPITAL_CAMA_A, "A")
    hospitalB = Hospital(env, HOSPITAL_CAMA_B, "B")
    for i in range(infectados):
        asignar_hospital(env, hospitalA, hospitalB, i)
    paciente = infectados
    while True:
        yield env.timeout(1)
        for i in range(tasa_crecimiento):
            paciente += 1
            asignar_hospital(env, hospitalA, hospitalB, paciente)

# %%
def asignar_hospital(env, hospitalA, hospitalB, paciente):
    hosp_esc = random.randint(1,2)
    if (hosp_esc == 1):
        print("Llega el paciente ", paciente, " al hospital 'A' en el tiempotiempo ", env.now)
        env.process(ingreso_paciente(env, hospitalA, paciente))
    else:
        print("Llega el paciente ", paciente, " al hospital 'B' en el tiempo ", env.now)
        env.process(ingreso_paciente(env, hospitalB, paciente))

# %%
print("Simulación")
env=simpy.Environment()
env.process(ejecutar(env,TASA_CRECIMIENTO, INFECTADOS))
env.run(until=DIAS_SIMULACION)
# Out:
# Simulación
# Llega el paciente  0  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  1  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  2  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  3  al hospital 'B' en el tiempo  0
# Llega el paciente  4  al hospital 'B' en el tiempo  0
# Llega el paciente  5  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  6  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  7  al hospital 'B' en el tiempo  0
# Llega el paciente  8  al hospital 'B' en el tiempo  0
# Llega el paciente  9  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  10  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  11  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  12  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  13  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  14  al hospital 'B' en el tiempo  0
# Llega el paciente  15  al hospital 'B' en el tiempo  0
# Llega el paciente  16  al hospital 'B' en el tiempo  0
# Llega el paciente  17  al hospital 'A' en el tiempotiempo  0
# Llega el paciente  18  al hospital 'B' en el tiempo  0
# Llega el paciente  19  al hospital 'A' en el tiempotiempo  0
# El paciente no presenta covid :  1  hospital  A
# El paciente no presenta covid :  4  hospital  B
# El paciente no presenta covid :  5  hospital  A
# El paciente no presenta covid :  6  hospital  A
# El paciente no presenta covid :  8  hospital  B
# El paciente no presenta covid :  9  hospital  A
# El paciente no presenta covid :  11  hospital  A
# El paciente no presenta covid :  14  hospital  B
# El paciente no presenta covid :  15  hospital  B
# El paciente no presenta covid :  17  hospital  A
# El paciente no presenta covid :  18  hospital  B
# El paciente no presenta covid :  19  hospital  A
# Al paciente:  0  se le asigna una cama   hospital  A
# Al paciente:  2  se le asigna una cama   hospital  A
# Al paciente:  3  se le asigna una cama   hospital  B
# Al paciente:  7  se le asigna una cama   hospital  B
# Al paciente:  10  se le asigna una cama   hospital  A
# Al paciente:  12  se le asigna una cama   hospital  A
# Al paciente:  13  se le asigna una cama   hospital  A
# Al paciente:  16  se le asigna una cama   hospital  B
# Llega el paciente  21  al hospital 'B' en el tiempo  1
# Llega el paciente  22  al hospital 'B' en el tiempo  1
# Llega el paciente  23  al hospital 'B' en el tiempo  1
# Llega el paciente  24  al hospital 'B' en el tiempo  1
# Llega el paciente  25  al hospital 'A' en el tiempotiempo  1
# Llega el paciente  26  al hospital 'A' en el tiempotiempo  1
# Llega el paciente  27  al hospital 'A' en el tiempotiempo  1
# El paciente no presenta covid :  23  hospital  B
# El paciente no presenta covid :  24  hospital  B
# Al paciente:  21  se le asigna una cama   hospital  B
# Al paciente:  22  se le asigna una cama   hospital  B
# Al paciente:  25  se le asigna una cama   hospital  A
# Al paciente:  26  se le asigna una cama   hospital  A
# Al paciente:  27  se le asigna una cama   hospital  A
# Llega el paciente  28  al hospital 'B' en el tiempo  2
# Llega el paciente  29  al hospital 'A' en el tiempotiempo  2
# Llega el paciente  30  al hospital 'A' en el tiempotiempo  2
# Llega el paciente  31  al hospital 'B' en el tiempo  2
# Llega el paciente  32  al hospital 'A' en el tiempotiempo  2
# Llega el paciente  33  al hospital 'A' en el tiempotiempo  2
# Llega el paciente  34  al hospital 'A' en el tiempotiempo  2
# El paciente no presenta covid :  28  hospital  B
# Al paciente:  29  se le asigna una cama   hospital  A
# Al paciente:  30  se le asigna una cama   hospital  A
# Al paciente:  31  se le asigna una cama   hospital  B
# Llega el paciente  35  al hospital 'B' en el tiempo  3
# Llega el paciente  36  al hospital 'A' en el tiempotiempo  3
# Llega el paciente  37  al hospital 'A' en el tiempotiempo  3
# Llega el paciente  38  al hospital 'A' en el tiempotiempo  3
# Llega el paciente  39  al hospital 'A' en el tiempotiempo  3
# Llega el paciente  40  al hospital 'A' en el tiempotiempo  3
# Llega el paciente  41  al hospital 'B' en el tiempo  3
# El paciente no presenta covid :  36  hospital  A
# El paciente no presenta covid :  38  hospital  A
# El paciente  33  en el hospital  A  espero  1  dias y fallece no hay camas
# Al paciente:  35  se le asigna una cama   hospital  B
# Al paciente:  41  se le asigna una cama   hospital  B
# Llega el paciente  42  al hospital 'B' en el tiempo  4
# Llega el paciente  43  al hospital 'A' en el tiempotiempo  4
# Llega el paciente  44  al hospital 'B' en el tiempo  4
# Llega el paciente  45  al hospital 'A' en el tiempotiempo  4
# Llega el paciente  46  al hospital 'B' en el tiempo  4
# Llega el paciente  47  al hospital 'A' en el tiempotiempo  4
# Llega el paciente  48  al hospital 'B' en el tiempo  4
# El paciente no presenta covid :  42  hospital  B
# El paciente no presenta covid :  45  hospital  A
# El paciente no presenta covid :  47  hospital  A
# El paciente no presenta covid :  48  hospital  B
# El paciente  32  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  34  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  40  en el hospital  A  espero  1  dias y fallece no hay camas
# Al paciente:  44  se le asigna una cama   hospital  B
# Al paciente:  46  se le asigna una cama   hospital  B
# El paciente terminó de atenderse:  3  tiempo de salida:  5  hospital  B
# El paciente terminó de atenderse:  7  tiempo de salida:  5  hospital  B
# Llega el paciente  49  al hospital 'B' en el tiempo  5
# Llega el paciente  50  al hospital 'B' en el tiempo  5
# Llega el paciente  51  al hospital 'A' en el tiempotiempo  5
# Llega el paciente  52  al hospital 'A' en el tiempotiempo  5
# Llega el paciente  53  al hospital 'B' en el tiempo  5
# Llega el paciente  54  al hospital 'B' en el tiempo  5
# Llega el paciente  55  al hospital 'B' en el tiempo  5
# El paciente no presenta covid :  51  hospital  A
# El paciente no presenta covid :  52  hospital  A
# El paciente no presenta covid :  53  hospital  B
# El paciente no presenta covid :  54  hospital  B
# Al paciente:  49  se le asigna una cama   hospital  B
# Al paciente:  50  se le asigna una cama   hospital  B
# El paciente terminó de atenderse:  0  tiempo de salida:  6  hospital  A
# El paciente terminó de atenderse:  13  tiempo de salida:  6  hospital  A
# Llega el paciente  56  al hospital 'A' en el tiempotiempo  6
# Llega el paciente  57  al hospital 'A' en el tiempotiempo  6
# Llega el paciente  58  al hospital 'B' en el tiempo  6
# Llega el paciente  59  al hospital 'A' en el tiempotiempo  6
# Llega el paciente  60  al hospital 'A' en el tiempotiempo  6
# Llega el paciente  61  al hospital 'B' en el tiempo  6
# Llega el paciente  62  al hospital 'A' en el tiempotiempo  6
# El paciente no presenta covid :  61  hospital  B
# El paciente no presenta covid :  62  hospital  A
# El paciente  39  en el hospital  A  espero  3  dias y fallece no hay camas
# Al paciente:  37  se le asigna una cama   hospital  A
# Al paciente:  43  se le asigna una cama   hospital  A
# El paciente terminó de atenderse:  27  tiempo de salida:  7  hospital  A
# Llega el paciente  63  al hospital 'A' en el tiempotiempo  7
# Llega el paciente  64  al hospital 'B' en el tiempo  7
# Llega el paciente  65  al hospital 'A' en el tiempotiempo  7
# Llega el paciente  66  al hospital 'B' en el tiempo  7
# Llega el paciente  67  al hospital 'A' en el tiempotiempo  7
# Llega el paciente  68  al hospital 'B' en el tiempo  7
# Llega el paciente  69  al hospital 'B' en el tiempo  7
# El paciente no presenta covid :  64  hospital  B
# El paciente no presenta covid :  66  hospital  B
# El paciente no presenta covid :  69  hospital  B
# El paciente  55  en el hospital  B  espero  2  dias y fallece no hay camas
# Al paciente:  56  se le asigna una cama   hospital  A
# Llega el paciente  70  al hospital 'B' en el tiempo  8
# Llega el paciente  71  al hospital 'A' en el tiempotiempo  8
# Llega el paciente  72  al hospital 'B' en el tiempo  8
# Llega el paciente  73  al hospital 'A' en el tiempotiempo  8
# Llega el paciente  74  al hospital 'A' en el tiempotiempo  8
# Llega el paciente  75  al hospital 'B' en el tiempo  8
# Llega el paciente  76  al hospital 'A' en el tiempotiempo  8
# El paciente no presenta covid :  75  hospital  B
# El paciente no presenta covid :  76  hospital  A
# El paciente  58  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  63  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  65  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  67  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  68  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente terminó de atenderse:  29  tiempo de salida:  9  hospital  A
# Llega el paciente  77  al hospital 'A' en el tiempotiempo  9
# Llega el paciente  78  al hospital 'A' en el tiempotiempo  9
# Llega el paciente  79  al hospital 'B' en el tiempo  9
# Llega el paciente  80  al hospital 'B' en el tiempo  9
# Llega el paciente  81  al hospital 'B' en el tiempo  9
# Llega el paciente  82  al hospital 'B' en el tiempo  9
# Llega el paciente  83  al hospital 'B' en el tiempo  9
# El paciente no presenta covid :  77  hospital  A
# El paciente no presenta covid :  78  hospital  A
# El paciente no presenta covid :  79  hospital  B
# El paciente no presenta covid :  83  hospital  B
# El paciente  57  en el hospital  A  espero  3  dias y fallece no hay camas
# El paciente  72  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  59  se le asigna una cama   hospital  A
# El paciente terminó de atenderse:  2  tiempo de salida:  10  hospital  A
# El paciente terminó de atenderse:  21  tiempo de salida:  10  hospital  B
# El paciente terminó de atenderse:  49  tiempo de salida:  10  hospital  B
# Llega el paciente  84  al hospital 'B' en el tiempo  10
# Llega el paciente  85  al hospital 'B' en el tiempo  10
# Llega el paciente  86  al hospital 'A' en el tiempotiempo  10
# Llega el paciente  87  al hospital 'B' en el tiempo  10
# Llega el paciente  88  al hospital 'A' en el tiempotiempo  10
# Llega el paciente  89  al hospital 'A' en el tiempotiempo  10
# Llega el paciente  90  al hospital 'A' en el tiempotiempo  10
# El paciente no presenta covid :  84  hospital  B
# El paciente no presenta covid :  86  hospital  A
# El paciente no presenta covid :  88  hospital  A
# El paciente no presenta covid :  89  hospital  A
# El paciente no presenta covid :  90  hospital  A
# El paciente  81  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  82  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  60  se le asigna una cama   hospital  A
# Al paciente:  70  se le asigna una cama   hospital  B
# Al paciente:  80  se le asigna una cama   hospital  B
# El paciente terminó de atenderse:  26  tiempo de salida:  11  hospital  A
# El paciente terminó de atenderse:  30  tiempo de salida:  11  hospital  A
# Llega el paciente  91  al hospital 'A' en el tiempotiempo  11
# Llega el paciente  92  al hospital 'B' en el tiempo  11
# Llega el paciente  93  al hospital 'B' en el tiempo  11
# Llega el paciente  94  al hospital 'A' en el tiempotiempo  11
# Llega el paciente  95  al hospital 'A' en el tiempotiempo  11
# Llega el paciente  96  al hospital 'A' en el tiempotiempo  11
# Llega el paciente  97  al hospital 'B' en el tiempo  11
# El paciente no presenta covid :  94  hospital  A
# El paciente  71  en el hospital  A  espero  3  dias y fallece no hay camas
# Al paciente:  73  se le asigna una cama   hospital  A
# Al paciente:  74  se le asigna una cama   hospital  A
# El paciente terminó de atenderse:  43  tiempo de salida:  12  hospital  A
# Llega el paciente  98  al hospital 'B' en el tiempo  12
# Llega el paciente  99  al hospital 'A' en el tiempotiempo  12
# Llega el paciente  100  al hospital 'B' en el tiempo  12
# Llega el paciente  101  al hospital 'A' en el tiempotiempo  12
# Llega el paciente  102  al hospital 'B' en el tiempo  12
# Llega el paciente  103  al hospital 'A' en el tiempotiempo  12
# Llega el paciente  104  al hospital 'B' en el tiempo  12
# El paciente no presenta covid :  98  hospital  B
# El paciente  87  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  91  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  95  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  97  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  96  se le asigna una cama   hospital  A
# El paciente terminó de atenderse:  16  tiempo de salida:  13  hospital  B
# El paciente terminó de atenderse:  22  tiempo de salida:  13  hospital  B
# El paciente terminó de atenderse:  25  tiempo de salida:  13  hospital  A
# Llega el paciente  105  al hospital 'B' en el tiempo  13
# Llega el paciente  106  al hospital 'A' en el tiempotiempo  13
# Llega el paciente  107  al hospital 'B' en el tiempo  13
# Llega el paciente  108  al hospital 'B' en el tiempo  13
# Llega el paciente  109  al hospital 'B' en el tiempo  13
# Llega el paciente  110  al hospital 'B' en el tiempo  13
# Llega el paciente  111  al hospital 'B' en el tiempo  13
# El paciente no presenta covid :  107  hospital  B
# El paciente no presenta covid :  108  hospital  B
# El paciente no presenta covid :  109  hospital  B
# El paciente  85  en el hospital  B  espero  3  dias y fallece no hay camas
# El paciente  93  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  100  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  102  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  92  se le asigna una cama   hospital  B
# Al paciente:  104  se le asigna una cama   hospital  B
# Al paciente:  99  se le asigna una cama   hospital  A
# El paciente terminó de atenderse:  10  tiempo de salida:  14  hospital  A
# El paciente terminó de atenderse:  12  tiempo de salida:  14  hospital  A
# El paciente terminó de atenderse:  46  tiempo de salida:  14  hospital  B
# Llega el paciente  112  al hospital 'A' en el tiempotiempo  14
# Llega el paciente  113  al hospital 'B' en el tiempo  14
# Llega el paciente  114  al hospital 'B' en el tiempo  14
# Llega el paciente  115  al hospital 'A' en el tiempotiempo  14
# Llega el paciente  116  al hospital 'A' en el tiempotiempo  14
# Llega el paciente  117  al hospital 'A' en el tiempotiempo  14
# Llega el paciente  118  al hospital 'B' en el tiempo  14
# El paciente no presenta covid :  115  hospital  A
# El paciente no presenta covid :  116  hospital  A
# El paciente no presenta covid :  117  hospital  A
# El paciente no presenta covid :  118  hospital  B
# El paciente  105  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  110  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  111  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  101  se le asigna una cama   hospital  A
# Al paciente:  103  se le asigna una cama   hospital  A
# Al paciente:  113  se le asigna una cama   hospital  B
# El paciente terminó de atenderse:  35  tiempo de salida:  15  hospital  B
# Llega el paciente  119  al hospital 'B' en el tiempo  15
# Llega el paciente  120  al hospital 'A' en el tiempotiempo  15
# Llega el paciente  121  al hospital 'A' en el tiempotiempo  15
# Llega el paciente  122  al hospital 'A' en el tiempotiempo  15
# Llega el paciente  123  al hospital 'B' en el tiempo  15
# Llega el paciente  124  al hospital 'A' en el tiempotiempo  15
# Llega el paciente  125  al hospital 'A' en el tiempotiempo  15
# Al paciente:  114  se le asigna una cama   hospital  B
# El paciente terminó de atenderse:  31  tiempo de salida:  16  hospital  B
# El paciente terminó de atenderse:  41  tiempo de salida:  16  hospital  B
# El paciente terminó de atenderse:  50  tiempo de salida:  16  hospital  B
# Llega el paciente  126  al hospital 'B' en el tiempo  16
# Llega el paciente  127  al hospital 'B' en el tiempo  16
# Llega el paciente  128  al hospital 'B' en el tiempo  16
# Llega el paciente  129  al hospital 'B' en el tiempo  16
# Llega el paciente  130  al hospital 'A' en el tiempotiempo  16
# Llega el paciente  131  al hospital 'A' en el tiempotiempo  16
# Llega el paciente  132  al hospital 'B' en el tiempo  16
# El paciente no presenta covid :  127  hospital  B
# El paciente no presenta covid :  128  hospital  B
# El paciente no presenta covid :  132  hospital  B
# El paciente  122  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  123  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  119  se le asigna una cama   hospital  B
# Al paciente:  126  se le asigna una cama   hospital  B
# Al paciente:  129  se le asigna una cama   hospital  B
# El paciente terminó de atenderse:  37  tiempo de salida:  17  hospital  A
# Llega el paciente  133  al hospital 'B' en el tiempo  17
# Llega el paciente  134  al hospital 'A' en el tiempotiempo  17
# Llega el paciente  135  al hospital 'A' en el tiempotiempo  17
# Llega el paciente  136  al hospital 'B' en el tiempo  17
# Llega el paciente  137  al hospital 'A' en el tiempotiempo  17
# Llega el paciente  138  al hospital 'A' en el tiempotiempo  17
# Llega el paciente  139  al hospital 'B' en el tiempo  17
# El paciente no presenta covid :  133  hospital  B
# El paciente no presenta covid :  137  hospital  A
# El paciente no presenta covid :  138  hospital  A
# El paciente no presenta covid :  139  hospital  B
# El paciente  120  en el hospital  A  espero  2  dias y fallece no hay camas
# Al paciente:  106  se le asigna una cama   hospital  A
# El paciente terminó de atenderse:  44  tiempo de salida:  18  hospital  B
# El paciente terminó de atenderse:  70  tiempo de salida:  18  hospital  B
# El paciente terminó de atenderse:  80  tiempo de salida:  18  hospital  B
# Llega el paciente  140  al hospital 'A' en el tiempotiempo  18
# Llega el paciente  141  al hospital 'B' en el tiempo  18
# Llega el paciente  142  al hospital 'A' en el tiempotiempo  18
# Llega el paciente  143  al hospital 'B' en el tiempo  18
# Llega el paciente  144  al hospital 'A' en el tiempotiempo  18
# Llega el paciente  145  al hospital 'B' en el tiempo  18
# Llega el paciente  146  al hospital 'B' en el tiempo  18
# El paciente no presenta covid :  142  hospital  A
# El paciente no presenta covid :  145  hospital  B
# El paciente  134  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  136  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  141  se le asigna una cama   hospital  B
# Al paciente:  143  se le asigna una cama   hospital  B
# Al paciente:  146  se le asigna una cama   hospital  B
# El paciente terminó de atenderse:  60  tiempo de salida:  19  hospital  A
# Llega el paciente  147  al hospital 'A' en el tiempotiempo  19
# Llega el paciente  148  al hospital 'A' en el tiempotiempo  19
# Llega el paciente  149  al hospital 'A' en el tiempotiempo  19
# Llega el paciente  150  al hospital 'B' en el tiempo  19
# Llega el paciente  151  al hospital 'B' en el tiempo  19
# Llega el paciente  152  al hospital 'A' en el tiempotiempo  19
# Llega el paciente  153  al hospital 'A' en el tiempotiempo  19
# El paciente no presenta covid :  148  hospital  A
# El paciente no presenta covid :  149  hospital  A
# El paciente no presenta covid :  151  hospital  B
# El paciente no presenta covid :  153  hospital  A
# El paciente  112  en el hospital  A  espero  5  dias y fallece no hay camas
# El paciente  125  en el hospital  A  espero  4  dias y fallece no hay camas
# El paciente  130  en el hospital  A  espero  3  dias y fallece no hay camas
# El paciente  135  en el hospital  A  espero  2  dias y fallece no hay camas
# Al paciente:  121  se le asigna una cama   hospital  A

# %%
print("<----------Resultados pacientes------->")

print("******Pacientes recuperados****** ")
print(persona_recuperadas)
print("*****Pacientes fallecidos********")
print(persona_fallecidas)
# Out:
# <----------Resultados pacientes------->
# ******Pacientes recuperados******
# {5: 2, 6: 2, 7: 1, 9: 1, 10: 2, 11: 1, 12: 1, 13: 3, 14: 3, 15: 1, 16: 3, 17: 1, 18: 3, 19: 1}
# *****Pacientes fallecidos********
# {3: 1, 4: 3, 6: 1, 7: 1, 8: 5, 9: 2, 10: 3, 11: 2, 12: 4, 13: 4, 14: 3, 16: 2, 17: 1, 18: 2, 19: 4}

# %%
datos=sorted(persona_recuperadas.items()) 
x, y =zip(*datos) 
pp.figure(figsize=(15,10))
pp.plot(x,y,linewidth=2,color='green') 
pp.scatter(x,y,color='red') 
pp.title("Pacientes Recuperados",color="green",size=20)
pp.grid(True) 
pp.show()

# %%
if (persona_fallecidas):
    datos=sorted(persona_fallecidas.items())
    pp.figure(figsize=(15,10))
    x, y =zip(*datos) 
    pp.plot(x,y,linewidth=2,color='red') 
    pp.scatter(x,y,color='black') 
    pp.title("Pacientes Fallecidos",color="red",size=20)
    pp.grid(True) 
    pp.show()
